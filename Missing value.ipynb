# %%
import pandas as pd
import numpy as np
import os
path = 'D:\Term 1\EDA\Workspace'
os.chdir(path)

# %%
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,5)

# %%
election = pd.read_excel('Election data base.xlsx')
election.head()
# Out:
#           st_name    year  ac_no    ac_name ac_type  \
# 0  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 1  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 2  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 3  Andhra Pradesh  1978.0      1  Ichapuram     GEN
# 4  Andhra Pradesh  1978.0      1  Ichapuram     GEN
#
#                    cand_name cand_sex                     partyname  \
# 0           Manabala Ramarao        M                   Independent
# 1                Appadu Sahu        M                   Independent
# 2           Uppada Rangababu        M      Indian National Congress
# 3       Kalla Balarama Swamy        M  Indian National Congress (I)
# 4  Bendalam Venkatesam Sarma        M                  Janata Party
#
#   partyabbre  totvotpoll  electors
# 0        IND       813.0     83247
# 1        IND      1743.0     83247
# 2        INC      4427.0     83247
# 3     INC(I)     19805.0     83247
# 4        JNP     34251.0     83247

# %%
null_value = election.isnull().sum()
null_value
# Out:
# st_name           0
# year              0
# ac_no             0
# ac_name       16083
# ac_type           0
# cand_name         1
# cand_sex       5302
# partyname         0
# partyabbre     2706
# totvotpoll        7
# electors          0
# dtype: int64

# %%
election.shape
# Out:
# (327294, 11)

# %%
p = (null_value/len(election.index))*100
p
# Out:
# st_name       0.000000
# year          0.000000
# ac_no         0.000000
# ac_name       4.913931
# ac_type       0.000000
# cand_name     0.000306
# cand_sex      1.619950
# partyname     0.000000
# partyabbre    0.826780
# totvotpoll    0.002139
# electors      0.000000
# dtype: float64

# %%
## Plotting the missing value

sns.heatmap(election.isnull(),cbar = False)

# %%
## Filling the missing value by 0 in totvotpoll

election['fill_by_zero'] = election['totvotpoll'].fillna(0)
null_value = election.isnull().sum()
null_value
# Out:
# st_name             0
# year                0
# ac_no               0
# ac_name         16083
# ac_type             0
# cand_name           1
# cand_sex         5302
# partyname           0
# partyabbre       2706
# totvotpoll          7
# electors            0
# fill_by_zero        0
# dtype: int64

# %%
#sikkim and 2016

mean_tot = election['totvotpoll'].mean()

election['fill_by_mean'] = election['totvotpoll'].fillna(mean_tot)

# Lets filter the value for sikkim and year 2004

sikkim_data = election[(election['st_name'] == 'Sikkim')]
sikkim_data_missing = sikkim_data[(sikkim_data['year'] == 2004)]
sikkim_data_missing
# Out:
#        st_name    year  ac_no           ac_name ac_type  \
# 229199  Sikkim  2004.0      1            Yoksam     GEN
# 229200  Sikkim  2004.0      1            Yoksam     GEN
# 229201  Sikkim  2004.0      1            Yoksam     GEN
# 229202  Sikkim  2004.0      2         Tashiding      BL
# 229203  Sikkim  2004.0      2         Tashiding      BL
# 229204  Sikkim  2004.0      2         Tashiding      BL
# 229205  Sikkim  2004.0      3           Geyzing     GEN
# 229206  Sikkim  2004.0      3           Geyzing     GEN
# 229207  Sikkim  2004.0      3           Geyzing     GEN
# 229208  Sikkim  2004.0      3           Geyzing     GEN
# 229209  Sikkim  2004.0      4            Dentam     GEN
# 229210  Sikkim  2004.0      4            Dentam     GEN
# 229211  Sikkim  2004.0      4            Dentam     GEN
# 229212  Sikkim  2004.0      5           Barmiok     GEN
# 229213  Sikkim  2004.0      5           Barmiok     GEN
# 229214  Sikkim  2004.0      5           Barmiok     GEN
# ...

# %%
election
# Out:
#                st_name    year  ac_no        ac_name ac_type  \
# 0       Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 1       Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 2       Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 3       Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 4       Andhra Pradesh  1978.0      1      Ichapuram     GEN
# 5       Andhra Pradesh  1978.0      2        Sompeta     GEN
# 6       Andhra Pradesh  1978.0      2        Sompeta     GEN
# 7       Andhra Pradesh  1978.0      2        Sompeta     GEN
# 8       Andhra Pradesh  1978.0      3        Tekkali     GEN
# 9       Andhra Pradesh  1978.0      3        Tekkali     GEN
# 10      Andhra Pradesh  1978.0      3        Tekkali     GEN
# 11      Andhra Pradesh  1978.0      4  Harishchandra     GEN
# 12      Andhra Pradesh  1978.0      4  Harishchandra     GEN
# 13      Andhra Pradesh  1978.0      4  Harishchandra     GEN
# ...

# %%
null_value
# Out:
# st_name           0
# year              0
# ac_no             0
# ac_name       16083
# ac_type           0
# cand_name         1
# cand_sex       5302
# partyname         0
# partyabbre     2706
# totvotpoll        7
# electors          0
# dtype: int64

# %%
## Dropping the null value

# Dropping rows
df = election.dropna()

print("Orginal data shape : ", election.shape)
print("shape after removing missing value from rows : ", df.shape)
# Out:
# Orginal data shape :  (327294, 11)
# shape after removing missing value from rows :  (303195, 11)

# %%
## Dropping the null value

# Dropping columns
df = election.dropna(axis = 1)

print("Orginal data shape : ", election.shape)
print("shape after removing missing value from rows : ", df.shape)
# Out:
# Orginal data shape :  (327294, 11)
# shape after removing missing value from rows :  (327294, 6)

# %%
# !pip install missingpy

# %%
from missingpy import KNNImputer

# %%
demo = pd.read_excel('Dummy_excel.xlsx')
demo
# Out:
#     X1  X2   X3  X4
# 0  9.0   6  NaN   8
# 1  4.0   2  6.0   3
# 2  NaN   9  4.0   9
# 3  6.0   6  2.0   5

# %%
## Creating the imputation object

imputer = KNNImputer(missing_values='NaN',metric='masked_euclidean',n_neighbors=2)
new_demo = imputer.fit_transform(demo)
new_demo
# Out:
# array([[9. , 6. , 3. , 8. ],
#        [4. , 2. , 6. , 3. ],
#        [7.5, 9. , 4. , 9. ],
#        [6. , 6. , 2. , 5. ]])

# %%
from pydataset import data
df = data('iris')
df
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %%
## Removing the last column

df1 = df.drop(columns=['Species'])
df1
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 1             5.1          3.5           1.4          0.2
# 2             4.9          3.0           1.4          0.2
# 3             4.7          3.2           1.3          0.2
# 4             4.6          3.1           1.5          0.2
# 5             5.0          3.6           1.4          0.2
# 6             5.4          3.9           1.7          0.4
# 7             4.6          3.4           1.4          0.3
# 8             5.0          3.4           1.5          0.2
# 9             4.4          2.9           1.4          0.2
# 10            4.9          3.1           1.5          0.1
# 11            5.4          3.7           1.5          0.2
# 12            4.8          3.4           1.6          0.2
# 13            4.8          3.0           1.4          0.1
# 14            4.3          3.0           1.1          0.1
# 15            5.8          4.0           1.2          0.2
# ...

# %%
from sklearn.cluster import KMeans

# %%
## Create the Kmeans object

km = KMeans(n_clusters=3, init='k-means++', random_state=1234)

# %%
## Fitting the model on my data

km.fit(df1.values)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=1234, tol=0.0001, verbose=0)

# %%
## Identifing the centroids cordinate

km.cluster_centers_
# Out:
# array([[5.006     , 3.428     , 1.462     , 0.246     ],
#        [5.9016129 , 2.7483871 , 4.39354839, 1.43387097],
#        [6.85      , 3.07368421, 5.74210526, 2.07105263]])

# %%
## Creating the column in our data set

df1['Cluster'] = km.predict(df1.values)
df1
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Cluster
# 1             5.1          3.5           1.4          0.2        0
# 2             4.9          3.0           1.4          0.2        0
# 3             4.7          3.2           1.3          0.2        0
# 4             4.6          3.1           1.5          0.2        0
# 5             5.0          3.6           1.4          0.2        0
# 6             5.4          3.9           1.7          0.4        0
# 7             4.6          3.4           1.4          0.3        0
# 8             5.0          3.4           1.5          0.2        0
# 9             4.4          2.9           1.4          0.2        0
# 10            4.9          3.1           1.5          0.1        0
# 11            5.4          3.7           1.5          0.2        0
# 12            4.8          3.4           1.6          0.2        0
# 13            4.8          3.0           1.4          0.1        0
# ...

# %%
df1.groupby('Cluster').size()
# Out:
# Cluster
# 0    50
# 1    62
# 2    38
# dtype: int64

# %%
## Lets plot the scatter plot for sepal length and sepal width

from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,5)

plt.scatter(df1['Sepal.Length'], df1['Sepal.Width'], c = df1['Cluster'])
plt.xlabel('Sepal.Length')
plt.ylabel('Sepal.Width')

# Will also draw the centroids

plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], c = 'red', s = 100)

plt.show()

# %%
## Lets plot the scatter plot for sepal length and sepal width

from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,5)

plt.scatter(df1['Petal.Length'], df1['Petal.Width'], c = df1['Cluster'])
plt.xlabel('Petal.Length')
plt.ylabel('Petal.Width')

# Will also draw the centroids

plt.scatter(km.cluster_centers_[:,2], km.cluster_centers_[:,3], c = 'red', s = 100)

plt.show()

# %%
election
# Out:
#                st_name    year  ac_no           ac_name ac_type  \
# 0       Andhra Pradesh  1978.0      1         Ichapuram     GEN
# 1       Andhra Pradesh  1978.0      1         Ichapuram     GEN
# 2       Andhra Pradesh  1978.0      1         Ichapuram     GEN
# 3       Andhra Pradesh  1978.0      1         Ichapuram     GEN
# 4       Andhra Pradesh  1978.0      1         Ichapuram     GEN
# 5       Andhra Pradesh  1978.0      2           Sompeta     GEN
# 6       Andhra Pradesh  1978.0      2           Sompeta     GEN
# 7       Andhra Pradesh  1978.0      2           Sompeta     GEN
# 8       Andhra Pradesh  1978.0      3           Tekkali     GEN
# 9       Andhra Pradesh  1978.0      3           Tekkali     GEN
# 10      Andhra Pradesh  1978.0      3           Tekkali     GEN
# 11      Andhra Pradesh  1978.0      4     Harishchandra     GEN
# 12      Andhra Pradesh  1978.0      4     Harishchandra     GEN
# 13      Andhra Pradesh  1978.0      4     Harishchandra     GEN
# ...

# %%
df = election.groupby('st_name')['totvotpoll','electors'].mean().reset_index()
df.head()
# Out:
#              st_name    totvotpoll       electors
# 0     Andhra Pradesh  12888.341450  214573.167908
# 1  Arunachal Pradesh   2435.059347   13016.475204
# 2              Assam   8408.626607  102227.586949
# 3              Bihar   6436.221233  174116.294425
# 4       Chhattisgarh  11302.725093  175266.152989

# %%
df1 = df[['totvotpoll','electors']]
df1.head()
# Out:
#      totvotpoll       electors
# 0  12888.341450  214573.167908
# 1   2435.059347   13016.475204
# 2   8408.626607  102227.586949
# 3   6436.221233  174116.294425
# 4  11302.725093  175266.152989

# %%
df1.shape
# Out:
# (30, 3)

# %%
## Create the Kmeans object

km = KMeans(n_clusters=3, init='k-means++', random_state=1234)

# %%
## Fitting the model on my data

km.fit(df1.values)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=1234, tol=0.0001, verbose=0)

# %%
## Creating the column in our data set

df1['Cluster'] = km.predict(df1.values)
df1.head()
# Out:
#      totvotpoll       electors  Cluster
# 0  12888.341450  214573.167908        1
# 1   2435.059347   13016.475204        0
# 2   8408.626607  102227.586949        2
# 3   6436.221233  174116.294425        1
# 4  11302.725093  175266.152989        1

# %%
df1.groupby('Cluster').size()
# Out:
# Cluster
# 0    11
# 1     9
# 2    10
# dtype: int64

# %%
km.cluster_centers_
# Out:
# array([[  4023.36286569,  28297.78994336],
#        [ 10288.6312337 , 195898.29285355],
#        [  9785.1653967 , 127631.26518   ]])

# %%
## Lets plot the scatter plot for sepal length and sepal width

from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,5)

plt.scatter(df1['totvotpoll'], df1['electors'], c = df1['Cluster'])
plt.xlabel('total vote poll')
plt.ylabel('electors')

# Will also draw the centroids

plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], c = 'red', s = 100)

plt.show()

# %%
from pydataset import data
df = data('iris')
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
## Removing the last column

df1 = df.drop(columns=['Species'])
df1.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 1           5.1          3.5           1.4          0.2
# 2           4.9          3.0           1.4          0.2
# 3           4.7          3.2           1.3          0.2
# 4           4.6          3.1           1.5          0.2
# 5           5.0          3.6           1.4          0.2

# %%
cluster_error = []

for i in range(1,15):
    kmeans = KMeans(n_clusters=i,init='k-means++',random_state=1234)
    kmeans.fit(df1.values)
    cluster_error.append(kmeans.inertia_)

# %%
cluster_error
# Out:
# [681.3706,
#  152.34795176035792,
#  78.85144142614601,
#  57.25600931571815,
#  46.44618205128205,
#  39.054977867477874,
#  34.80586723582575,
#  30.06459307359308,
#  28.340758422949605,
#  26.023203661327237,
#  24.604139541623404,
#  23.38079210847632,
#  21.453079775058107,
#  20.399632232755803]

# %%
# %matplotlib inline
plt.plot(range(1,15), cluster_error, marker = 'o')

# %%
df = election.groupby('st_name')['totvotpoll','electors'].mean().reset_index()
df.head()
# Out:
#              st_name    totvotpoll       electors
# 0     Andhra Pradesh  12888.341450  214573.167908
# 1  Arunachal Pradesh   2435.059347   13016.475204
# 2              Assam   8408.626607  102227.586949
# 3              Bihar   6436.221233  174116.294425
# 4       Chhattisgarh  11302.725093  175266.152989

# %%
df1 = df[['totvotpoll','electors']]
df1.head()
# Out:
#      totvotpoll       electors
# 0  12888.341450  214573.167908
# 1   2435.059347   13016.475204
# 2   8408.626607  102227.586949
# 3   6436.221233  174116.294425
# 4  11302.725093  175266.152989

# %%
cluster_error = []

for i in range(1,15):
    kmeans = KMeans(n_clusters=i,init='k-means++',random_state=1234)
    kmeans.fit(df1.values)
    cluster_error.append(kmeans.inertia_)

# %%
cluster_error
# Out:
# [154678321584.86826,
#  33111374680.10283,
#  11568860682.75126,
#  7124162136.618815,
#  4034277487.022835,
#  2792550851.5730667,
#  2084794576.4755216,
#  1493193009.707828,
#  954129080.9959118,
#  762664863.1929747,
#  659783404.1832554,
#  492051792.96261084,
#  402587586.97937715,
#  304723230.8078122]

# %%
# %matplotlib inline
plt.plot(range(1,15), cluster_error, marker = 'o')
